# %% [markdown]
# # FROM THE DESIRED `~/WORKBOOK` DIRECTORY

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Python Packages

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# alembic                       1.4.1
# altair                        4.1.0
# anyio                         2.2.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         20.3.0
# Babel                         2.9.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.9.3
# bleach                        3.3.0
# blinker                       1.4
# blis                          0.7.4
# bokeh                         2.3.1
# Boruta                        0.3
# Bottleneck                    1.3.2
# Brotli                        1.0.9
# brotlipy                      0.7.0
# cached-property               1.5.2
# catalogue                     1.0.0
# certifi                       2020.12.5
# certipy                       0.1.3
# ...
